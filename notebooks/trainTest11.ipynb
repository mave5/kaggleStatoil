# %%
#==============================================================================
import os
os.environ["THEANO_FLAGS"] = "mode=FAST_RUN,device=gpu0,floatX=float32"

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import pdb
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Lambda, Activation
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D, GlobalAveragePooling2D
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam
from keras import backend as K
from matplotlib import pyplot as plt
# %matplotlib inline
import scipy
from sklearn.model_selection import ShuffleSplit
from scipy import misc, ndimage
from scipy.ndimage.interpolation import zoom
from scipy.ndimage import imread
import time
import datetime
# Out:
# Using Theano backend.
# WARNING (theano.sandbox.cuda): The cuda backend is deprecated and will be removed in the next release (v0.10).  Please switch to the gpuarray backend. You can get more information about how to switch at this URL:
#  https://github.com/Theano/Theano/wiki/Converting-to-the-new-gpu-back-end%28gpuarray%29
#
# Using gpu device 0: GeForce GTX TITAN X (CNMeM is enabled with initial size: 20.0% of memory, cuDNN 5110)

# %% [markdown]
# ### settings

# %%
#norm_type='zeroMeanUnitStd'
#norm_type='minus1plus1'
norm_type=None

netinfo='trainTest11'

# %% [markdown]
# ## utilities

# %%
def get_images(df):
    '''Create 3-channel 'images'. Return rescale-normalised images.'''
    images = []
    for i, row in df.iterrows():
        # Formulate the bands as 75x75 arrays
        band_1 = np.array(row['band_1']).reshape(75, 75)
        band_2 = np.array(row['band_2']).reshape(75, 75)
        #band_3 = band_1 / band_2

        # Rescale
        band_1 = (band_1 - band_1.min()) / (band_1.max() - band_1.min())
        band_2 = (band_2 - band_2.min()) / (band_2.max() - band_2.min())
        #b = (band_3 - band_3.min()) / (band_3.max() - band_3.min())

        b1b2 = np.dstack((band_1, band_2)).astype('float32')
        images.append(b1b2)
    images=np.array(images,'float32')
    images=np.transpose(images,(0,3,1,2))
    return images

def get_scaled_imgs(df):
    """
    basic function for reshaping and rescaling data as images
    """
    imgs = []
    
    for i, row in df.iterrows():
        #make 75x75 image
        band_1 = np.array(row['band_1']).reshape(75, 75)
        band_2 = np.array(row['band_2']).reshape(75, 75)
        band_3 = band_1 + band_2 # plus since log(x*y) = log(x) + log(y)
        
        # Rescale
        a = (band_1 - band_1.mean()) / (band_1.max() - band_1.min())
        b = (band_2 - band_2.mean()) / (band_2.max() - band_2.min())
        c = (band_3 - band_3.mean()) / (band_3.max() - band_3.min())

        imgs.append(np.dstack((a, b, c)))
    imgs=np.array(imgs,'float32')
    imgs=np.transpose(imgs,(0,3,1,2))
        
    return np.array(imgs)    


def array_stats(X):
    X=np.asarray(X)
    print ('array shape and type: ',X.shape, X.dtype)
    #print 'min: %.3f, max:%.3f, avg: %.3f, std:%.3f' %(np.min(X),np.max(X),np.mean(X),np.std(X))
    print ('min: {}, max: {}, avg: {:.3}, std:{:.3}'.format( np.min(X),np.max(X),np.mean(X),np.std(X)))
    
    
def preprocess(X,xnormType=None):
    if xnormType=='minus1plus1':
        X=X.astype('float32')
        X/=np.max(X)
        X-=0.5
        X=X*2
    elif xnormType=='zeroMeanUnitStd':
        X=X.astype('float32')
        # we do this per channel
        for c in range(X.shape[1]):
            X[:,c]-=np.mean(X[:,c])
            stdXc=np.std(X[:,c])
            if stdXc>0.0:
                X[:,c]/=stdXc
    else:
        print('no normalization!')
    return X
    
# train test model
def train_test_model(X_train,y_train,X_test,y_test,params_train):
    foldnm=params_train['foldnm']  
    pre_train=params_train['pre_train'] 
    batch_size=params_train['batch_size'] 
    augmentation=params_train['augmentation'] 
    path2weights=params_train['path2weights'] 
    print('batch_size: %s, Augmentation: %s' %(batch_size,augmentation))
    
    print 'fold %s training in progress ...' %foldnm
    # load last weights
    if pre_train== True:
        if  os.path.exists(path2weights):
            model.load_weights(path2weights)
            print 'previous weights loaded!'
        else:
            raise IOError('weights does not exist!!!')
    else:
        if  os.path.exists(path2weights):
            model.load_weights(path2weights)
            print (path2weights)
            print ('previous weights loaded!')
            train_status='previous weights'
            return train_status
    
    # path to csv file to save scores
    path2scorescsv = weightfolder+'/scores.csv'
    first_row = 'train,test'
    with open(path2scorescsv, 'w+') as f:
        f.write(first_row + '\n')
           
    # Fit the model
    start_time=time.time()
    scores_test=[]
    scores_train=[]
    if params_train['loss']=='dice': 
        best_score = 0
        previous_score = 0
    else:
        best_score = 1e6
        previous_score = 1e6
    patience = 0
    
    # convert class vectors to binary class matrices
    #y_train = np_utils.to_categorical(y_train, nb_outputs)
    #y_test = np_utils.to_categorical(y_test, nb_outputs)
    
    
    for epoch in range(params_train['nbepoch']):
    
        print ('epoch: %s,  Current Learning Rate: %.1e' %(epoch,model.optimizer.lr.get_value()))
        #seed = np.random.randint(0, 999999)
    
        if augmentation:
            batches=0
            bs=len(X_train)#batch_size*10
            for X_batch, y_batch in datagen.flow(X_train, y_train, batch_size=bs,shuffle=True):
                X_batch=preprocess(X_batch,norm_type)
                hist=model.fit(X_batch, y_batch, batch_size=batch_size,nb_epoch=1, verbose=0)
                batches += 1
                if batches >= len(X_train) / bs:
                    # we need to break the loop by hand because
                    # the generator loops indefinitely
                    break
        else:
            hist=model.fit(preprocess(X_train,norm_type)[:,:,np.newaxis], y_train, batch_size=batch_size,nb_epoch=1, verbose=0)
            
        # evaluate on test and train data
        score_test=model.evaluate(preprocess(X_test,norm_type),y_test,verbose=0)
        score_train=np.mean(hist.history['loss'])
       
        print ('score_train: %s, score_test: %s' %(score_train,score_test))
        scores_test=np.append(scores_test,score_test)
        scores_train=np.append(scores_train,score_train)    

        # check for improvement    
        if (score_test<=best_score):
            print ("!!!!!!!!!!!!!!!!!!!!!!!!!!! viva, improvement!!!!!!!!!!!!!!!!!!!!!!!!!!!") 
            best_score = score_test
            patience = 0
            model.save_weights(path2weights)  
            model.save(weightfolder+'/model.h5')
            
        # learning rate schedule
        if score_test>previous_score:
            #print "Incrementing Patience."
            patience += 1

        # learning rate schedule                
        if patience == params_train['max_patience']:
            params_train['learning_rate'] = params_train['learning_rate']/2
            print ("Upating Current Learning Rate to: ", params_train['learning_rate'])
            model.optimizer.lr.set_value(params_train['learning_rate'])
            print ("Loading the best weights again. best_score: ",best_score)
            model.load_weights(path2weights)
            patience = 0
        
        # save current test score
        previous_score = score_test    
        
        # store scores into csv file
        with open(path2scorescsv, 'a') as f:
            string = str([score_train,score_test])
            f.write(string + '\n')
           
    
    print ('model was trained!')
    elapsed_time=(time.time()-start_time)/60
    print ('elapsed time: %d  mins' %elapsed_time)      

    # train test progress plots
    plt.figure(figsize=(10,10))
    plt.plot(scores_test)
    plt.plot(scores_train)
    plt.title('train-validation progress',fontsize=20)
    plt.legend(('test','train'),fontsize=20)
    plt.xlabel('epochs',fontsize=20)
    plt.ylabel('loss',fontsize=20)
    plt.grid(True)
    plt.savefig(weightfolder+'/train_val_progress.png')
    #plt.show()
    
    print 'training completed!'
    train_status='completed!'
    return train_status

# %% [markdown]
# ### loading data

# %%
train = pd.read_json('../data/train.json')
#X=get_images(train)
X=get_scaled_imgs(train)
array_stats(X)

# labels
#y = to_categorical(train.is_iceberg.values,nb_classes=2)
y = train.is_iceberg.values

print('avg of labels:',y.mean())
# Out:
# ('array shape and type: ', (1604, 3, 75, 75), dtype('float32'))
# min: -0.727469801903, max: 0.85425567627, avg: 7.05e-12, std:0.0965
# ('avg of labels:', 0.46945137157107231)

# %% [markdown]
# #### visualize data

# %%
n1=np.random.randint(len(X))
plt.subplot(1,2,1)
plt.imshow(X[n1,0],cmap='gray');
plt.subplot(1,2,2)
plt.imshow(X[n1,1],cmap='gray');
plt.title(y[n1]);

# %%
from keras.layers import Input, merge, Convolution2D, MaxPooling2D, UpSampling2D,Dropout
from keras.layers import Activation,Reshape,Permute,Flatten,Dense
from keras.models import Model,Sequential
from keras.layers.wrappers import TimeDistributed
from keras.layers.recurrent import GRU
from keras.optimizers import RMSprop, Adam,Nadam
from keras.layers import GlobalAveragePooling1D,AveragePooling2D
from keras.layers.normalization import BatchNormalization
from keras.regularizers import l2
from keras.layers.advanced_activations import ELU,PReLU,LeakyReLU
from keras.preprocessing.image import ImageDataGenerator

def conv_block(x_input, num_filters,pool=True,norm=False,drop_rate=0.0,border_mode='valid',stride=1):
    x1 = Convolution2D(num_filters,3,3,subsample=(stride,stride),border_mode=border_mode,W_regularizer=l2(1e-4))(x_input)
    if norm:
        x1 = BatchNormalization(mode=2,axis=1)(x1)
        
    if drop_rate > 0.0:
        #x1 = GaussianDropout(drop_rate)(x1)
        x1 = Dropout(drop_rate)(x1)

    x1 = LeakyReLU(.1)(x1)
    if pool:
        x1 = MaxPooling2D()(x1)
    x_out = x1
    return x_out


def modelCnn(params):
    # input format: batch_size*timesteps*z*h*w    
    h=params['h']
    w=params['w']
    z=params['z']
    timesteps=params['timesteps']    
    lr=params['learning_rate']
    nb_output=params['nb_outputs']
    loss=params['loss']
    C=params['init_filters']
    border_mode=params['border_mode']
    base_display=params['base_display']
    stride=params['stride']
    dropOutRate=params['dropOutRate']
    optimizer=params['optimizer']
    kS=params['kernelSize']
    kI=params['kernelInit']
    bnEnable=params['batchNormEnable']
    iF=params['init_filters']
    
    xin = Input((z,h, w))
    x = conv_block(xin,C,norm=bnEnable,stride=stride,pool=True,drop_rate=dropOutRate,border_mode=border_mode) 
    #x = conv_block(x,C,norm=bnEnable,stride=stride,pool=False,drop_rate=dropOutRate,border_mode=border_mode)     
    

    x = conv_block(x,2*C,norm=bnEnable,pool=True,drop_rate=dropOutRate,border_mode=border_mode) 
    #x = conv_block(x,2*C,norm=bnEnable,pool=False,drop_rate=dropOutRate,border_mode=border_mode)     

    #by branching we reduce the #params
    x = conv_block(x,4*C,norm=bnEnable,pool=True,drop_rate=dropOutRate,border_mode=border_mode) 
    #x = conv_block(x,4*C,norm=bnEnable,pool=False,drop_rate=dropOutRate,border_mode=border_mode)     

    x = conv_block(x,8*C,norm=bnEnable,pool=True,drop_rate=dropOutRate,border_mode=border_mode)
    #x4 = conv_block(x4,8*C,norm=bnEnable,pool=False,drop_rate=dropOutRate,border_mode=border_mode)    

    # last layer of encoding    
    x=Flatten() (x)
    #x=Dense(512,activation='relu')(x)    
    #x=Dropout(dropOutRate)(x)

    #x=Dense(256,activation='relu')(x)    
    x=Dropout(dropOutRate)(x)
   
    x=Dense(nb_output, activation='sigmoid',W_regularizer=l2(1e-4))(x)
    
    model = Model(input=xin, output=x)
    
    
    if optimizer=='RMSprop':
        optimizer = RMSprop(lr)
    elif optimizer=='Adam':       
        optimizer = Adam(lr)
    elif optimizer=='Nadam':       
        optimizer = Nadam(lr,clipvalue=1.0)        
    model.compile(loss=loss, optimizer=optimizer)

    return model

# random data generator
datagen = ImageDataGenerator(featurewise_center=False,
        samplewise_center=False,
        featurewise_std_normalization=False,
        samplewise_std_normalization=False,
        zca_whitening=False,
        rotation_range=10,
        width_shift_range=0.10,
        height_shift_range=0.10,
        shear_range=0.1,
        zoom_range=0.10,
        channel_shift_range=0.0,
        fill_mode='constant',
        cval=0.0,
        horizontal_flip=True,
        vertical_flip=True,
        dim_ordering='th') 


_,z,h,w=X.shape
# training params
params_train={
    'h': h,
    'w': w,
    'z': z,
    'timesteps':None,
    'c':1,           
    'learning_rate': 3e-4,
    #'optimizer': 'Adam',
    'optimizer': 'Nadam',
    #'loss': 'categorical_crossentropy',
    'loss': 'binary_crossentropy',
    #'loss': 'mean_squared_error',
    'nbepoch': 500,
    'nb_outputs': 1,
    'init_filters': 10,    
    'max_patience': 30,
    'stride': 1,
    'fully_connected': False,
    'output_activation': 'sigmoid',
    'border_mode':'valid',
    'base_display': True,
    'dropOutRate': 0.2,
    'pre_train': False,
    'foldnm':1,
    'kernelSize':3,
    'kernelInit':'glorot_uniform',
    'batchNormEnable': False,
    'batch_size': 32,
    'augmentation': True,
    'path2weights': None,
}    


model=modelCnn(params_train)
model.summary()
# Out:
# /home/mra/anaconda2/lib/python2.7/site-packages/keras/backend/theano_backend.py:1500: UserWarning: DEPRECATION: the 'ds' parameter is not going to exist anymore as it is going to be replaced by the parameter 'ws'.
#   mode='max')
# /home/mra/anaconda2/lib/python2.7/site-packages/keras/backend/theano_backend.py:1500: UserWarning: DEPRECATION: the 'st' parameter is not going to exist anymore as it is going to be replaced by the parameter 'stride'.
#   mode='max')
# /home/mra/anaconda2/lib/python2.7/site-packages/keras/backend/theano_backend.py:1500: UserWarning: DEPRECATION: the 'padding' parameter is not going to exist anymore as it is going to be replaced by the parameter 'pad'.
#   mode='max')
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 3, 75, 75)     0
# ____________________________________________________________________________________________________
# convolution2d_1 (Convolution2D)  (None, 10, 73, 73)    280         input_1[0][0]
# ____________________________________________________________________________________________________
# dropout_1 (Dropout)              (None, 10, 73, 73)    0           convolution2d_1[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_1 (LeakyReLU)          (None, 10, 73, 73)    0           dropout_1[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_1 (MaxPooling2D)    (None, 10, 36, 36)    0           leakyrelu_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_2 (Convolution2D)  (None, 20, 34, 34)    1820        maxpooling2d_1[0][0]
# ____________________________________________________________________________________________________
# dropout_2 (Dropout)              (None, 20, 34, 34)    0           convolution2d_2[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_2 (LeakyReLU)          (None, 20, 34, 34)    0           dropout_2[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_2 (MaxPooling2D)    (None, 20, 17, 17)    0           leakyrelu_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_3 (Convolution2D)  (None, 40, 15, 15)    7240        maxpooling2d_2[0][0]
# ____________________________________________________________________________________________________
# dropout_3 (Dropout)              (None, 40, 15, 15)    0           convolution2d_3[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_3 (LeakyReLU)          (None, 40, 15, 15)    0           dropout_3[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_3 (MaxPooling2D)    (None, 40, 7, 7)      0           leakyrelu_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_4 (Convolution2D)  (None, 80, 5, 5)      28880       maxpooling2d_3[0][0]
# ____________________________________________________________________________________________________
# dropout_4 (Dropout)              (None, 80, 5, 5)      0           convolution2d_4[0][0]
# ____________________________________________________________________________________________________
# leakyrelu_4 (LeakyReLU)          (None, 80, 5, 5)      0           dropout_4[0][0]
# ____________________________________________________________________________________________________
# maxpooling2d_4 (MaxPooling2D)    (None, 80, 2, 2)      0           leakyrelu_4[0][0]
# ____________________________________________________________________________________________________
# flatten_1 (Flatten)              (None, 320)           0           maxpooling2d_4[0][0]
# ____________________________________________________________________________________________________
# dense_1 (Dense)                  (None, 1)             321         flatten_1[0][0]
# ====================================================================================================
# Total params: 38541
# ____________________________________________________________________________________________________

# %% [markdown]
# ### get current notebook name

# %%
#%%javascript
#var kernel = IPython.notebook.kernel;
#var thename = window.document.getElementById("notebook_name").innerHTML;
#var command = "theNotebook = " + "'"+thename+"'";
#kernel.execute(command)

# %%
n_folds=5
#skf = StratifiedKFold(n_splits=n_folds,random_state=321,shuffle=True)
#skf = KFold(n_splits=n_folds,random_state=234)
skf = ShuffleSplit(n_splits=n_folds, test_size=0.1, random_state=321)

# loop over folds
foldnm=0
scores_nfolds=[]

print ('wait ...')
for train_ind, test_ind in skf.split(X,y):
    foldnm+=1    
    print('fold %s' %foldnm)

    train_ind=list(np.sort(train_ind))
    test_ind=list(np.sort(test_ind))
    #print test_ind

    X_train,y_train=X[train_ind],y[train_ind]       
    X_test,y_test=X[test_ind],y[test_ind] 
    
    
    array_stats(X_train)
    array_stats(y_train)
    array_stats(X_test)
    array_stats(y_test)
    print ('-'*30)
    
    # exeriment name to record weights and scores
    experiment=netinfo+'_hw_'+str(h)+'by'+str(w)+'_initfilts_'+str(params_train['init_filters'])
    print ('experiment: %s' %experiment)

    # checkpoint
    weightfolder='./output/weights/'+experiment+'/fold'+str(foldnm)
    if  not os.path.exists(weightfolder):
        os.makedirs(weightfolder)
    print ('weights folder created')    
    
    # path to weights
    path2weights=weightfolder+"/weights.hdf5"
    path2model=weightfolder+"/model.hdf5"    
    
   # training params
    params_train['foldnm']=foldnm
    params_train['learning_rate']=3e-4
    params_train['path2weights']=path2weights
    model=modelCnn(params_train)
    #model.summary()

    
    # train test on fold #
    train_test_model(X_train,y_train,X_test,y_test,params_train)
    
    # loading best weights from training session
    if  os.path.exists(path2weights):
        model.load_weights(path2weights)
        print ('%s loaded!' %path2weights)
    else:
        raise IOError('weights does not exist!!!')

    score_test=model.evaluate(preprocess(X_test,norm_type),y_test,verbose=0)
    print ('score_test: %.5f' %(score_test))    
    print ('-' *30)
    # store scores for all folds
    scores_nfolds.append(score_test)

print ('average score for %s folds is %s' %(n_folds,np.mean(scores_nfolds)))
# Out:
# wait ...
# fold 1
# ('array shape and type: ', (1443, 3, 75, 75), dtype('float32'))
# min: -0.727469801903, max: 0.85425567627, avg: -1.78e-11, std:0.0964
# ('array shape and type: ', (1443,), dtype('int64'))
# min: 0, max: 1, avg: 0.456, std:0.498
# ('array shape and type: ', (161, 3, 75, 75), dtype('float32'))
# min: -0.682733356953, max: 0.838276922703, avg: -4.49e-11, std:0.097
# ('array shape and type: ', (161,), dtype('int64'))
# min: 0, max: 1, avg: 0.59, std:0.492
# ------------------------------
# experiment: trainTest11_hw_75by75_initfilts_10
# weights folder created
# batch_size: 32, Augmentation: True
# fold 1 training in progress ...
# epoch: 0,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.689966861977, score_test: 0.706130866679
# !!!!!!!!!!!!!!!!!!!!!!!!!!! viva, improvement!!!!!!!!!!!!!!!!!!!!!!!!!!!
# epoch: 1,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.656715039363, score_test: 0.670491462168
# !!!!!!!!!!!!!!!!!!!!!!!!!!! viva, improvement!!!!!!!!!!!!!!!!!!!!!!!!!!!
# epoch: 2,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.618203641802, score_test: 0.617500469922
# !!!!!!!!!!!!!!!!!!!!!!!!!!! viva, improvement!!!!!!!!!!!!!!!!!!!!!!!!!!!
# epoch: 3,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.569720124463, score_test: 0.837221750191
# epoch: 4,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0
  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.275927541069, score_test: 0.281024488973
# epoch: 119,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.26389537521, score_test: 0.275830672765
# epoch: 120,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.262262314842, score_test: 0.271768917208
# epoch: 121,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.264862106102, score_test: 0.265204840565
# !!!!!!!!!!!!!!!!!!!!!!!!!!! viva, improvement!!!!!!!!!!!!!!!!!!!!!!!!!!!
# epoch: 122,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.266791246165, score_test: 0.290311970696
# epoch: 123,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.274706427434, score_test: 0.274158583109
# epoch: 124,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.270573202141, score_test: 0.268300333378
# epoch: 125,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.267670364613, score_test: 0.262820340091
# !!!!!!!!!!!!!!!!!!!!!!!!!!! viva, improvement!!!!!!!!!!!!!!!!!!!!!!!!!!!
# epoch: 126,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.265820794546, score_test: 0.265235019767
# epoch: 127,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.254325935298, score_test: 0.263405937216
# epoch: 128,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.263349982451, score_test: 0.276543850114
# epoch: 129,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.249540874922, score_test: 0.275481859534
# epoch: 130,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.260295212765, score_test: 0.273435881975
# epoch: 131,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.259990341719, score_test: 0.262456472616
# !!!!!!!!!!!!!!!!!!!!!!!!!!! viva, improvement!!!!!!!!!!!!!!!!!!!!!!!!!!!
# epoch: 132,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.253512520717, score_test: 0.272245344723
# epoch: 133,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.251682193512, score_test: 0.3107116339
# epoch: 134,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.261561639912, score_test: 0.273847283043
# epoch: 135,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.254638870805, score_test: 0.279528951053
# epoch: 136,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.264196462113, score_test: 0.272124080184
# epoch: 137,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.253197762581, score_test: 0.270126570826
# epoch: 138,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.253263942856, score_test: 0.269015116721
# epoch: 139,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.266590657731, score_test: 0.268939252966
# epoch: 140,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.266786537729, score_test: 0.273468350772
# epoch: 141,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.265625698078, score_test: 0.280269515255
# epoch: 142,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.259666991595, score_test: 0.272983086035
# epoch: 143,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.26016910669, score_test: 0.262745956086
# epoch: 144,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.254546247397, score_test: 0.269147172478
# epoch: 145,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.260228189944, score_test: 0.271994874714
# epoch: 146,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.252567884105, score_test: 0.266299094473
# epoch: 147,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.26069676335, score_test: 0.343400045767
# epoch: 148,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.259612358203, score_test: 0.271404932004
# epoch: 149,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.247780666359, score_test: 0.265633153989
# epoch: 150,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.252085616635, score_test: 0.260107344722
# !!!!!!!!!!!!!!!!!!!!!!!!!!! viva, improvement!!!!!!!!!!!!!!!!!!!!!!!!!!!
# epoch: 151,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.250975704469, score_test: 0.276918580813
# epoch: 152,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.248041958174, score_test: 0.260740684797
# epoch: 153,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.245225484805, score_test: 0.263857549022
# epoch: 154,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.255610215854, score_test: 0.285082475091
# epoch: 155,  Current Learning Rate: 3.0e-04
# no normalization!
# no normalization!
# score_train: 0.263463811625, score_test: 0.377770015704
# epoch: 156,  Current Learning Rate: 3.0e-04
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-c84e0f26dabc> in <module>()
#      50
#      51     # train test on fold #
# ---> 52     train_test_model(X_train,y_train,X_test,y_test,params_train)
#      53
#      54     # loading best weights from training session
#
# <ipython-input-4-35eb6260e5e7> in train_test_model(X_train, y_train, X_test, y_test, params_train)
#     124             batches=0
#     125             bs=len(X_train)#batch_size*10
# --> 126             for X_batch, y_batch in datagen.flow(X_train, y_train, batch_size=bs,shuffle=True):
#     127                 X_batch=preprocess(X_batch,norm_type)
#     128                 hist=model.fit(X_batch, y_batch, batch_size=batch_size,nb_epoch=1, verbose=0)
#
# /home/mra/anaconda2/lib/python2.7/site-packages/keras/preprocessing/image.pyc in next(self)
#     494         for i, j in enumerate(index_array):
#     495             x = self.X[j]
# --> 496             x = self.image_data_generator.random_transform(x.astype('float32'))
#     497             x = self.image_data_generator.standardize(x)
#     498             batch_x[i] = x
#
# /home/mra/anaconda2/lib/python2.7/site-packages/keras/preprocessing/image.pyc in random_transform(self, x)
#     360         transform_matrix = transform_matrix_offset_center(transform_matrix, h, w)
#     361         x = apply_transform(x, transform_matrix, img_channel_index,
# --> 362                             fill_mode=self.fill_mode, cval=self.cval)
#     363         if self.channel_shift_range != 0:
#     364             x = random_channel_shift(x, self.channel_shift_range, img_channel_index)
#
# /home/mra/anaconda2/lib/python2.7/site-packages/keras/preprocessing/image.pyc in apply_transform(x, transform_matrix, channel_index, fill_mode, cval)
#     106     final_offset = transform_matrix[:2, 2]
#     107     channel_images = [ndi.interpolation.affine_transform(x_channel, final_affine_matrix,
# --> 108                       final_offset, order=0, mode=fill_mode, cval=cval) for x_channel in x]
#     109     x = np.stack(channel_images, axis=0)
#     110     x = np.rollaxis(x, 0, channel_index+1)
#
# /home/mra/anaconda2/lib/python2.7/site-packages/scipy/ndimage/interpolation.pyc in affine_transform(input, matrix, offset, output_shape, output, order, mode, cval, prefilter)
#     436     else:
#     437         _geometric_transform(filtered, None, None, matrix, offset,
# --> 438                              output, order, mode, cval, None, None)
#     439     return return_value
#     440
#
# /home/mra/anaconda2/lib/python2.7/site-packages/scipy/ndimage/interpolation.pyc in _geometric_transform(input, mapping, coordinates, matrix, offset, output, order, mode, cval, extra_arguments, extra_keywords)
#     130     _nd_image.geometric_transform(
#     131         input, mapping, coordinates, matrix, offset, output,
# --> 132         order, mode, cval, extra_arguments, extra_keywords)
#     133
#     134     if output is not None and not output.dtype.isnative:
#
# KeyboardInterrupt:

# %% [markdown]
# ## loading leaderboard data

# %%
# leaderboard
learder = pd.read_json('../data/test.json')
X_lb = get_images(learder )
array_stats(X_lb)

# %%
# prediction for nfolds
y_pred=[]
for foldnm in range(1,n_folds+1):
    
    # load weights
    experiment=netinfo+'_hw_'+str(h)+'by'+str(w)+'_initfilts_'+str(params_train['init_filters'])
    print ('experiment:', experiment)
    weightfolder='./output/weights/'+experiment+'/fold'+str(foldnm)
    # path to weights
    path2weights=weightfolder+"/weights.hdf5"
    if  os.path.exists(path2weights):
        model.load_weights(path2weights)
        print ('%s loaded!' %path2weights)
    else:
        raise IOError ('weights does not exist!')

    # prediction
    y_pred_perfold=model.predict(preprocess(X_lb,norm_type))
    print y_pred_perfold.shape    
    y_pred.append(y_pred_perfold)        
        
# reshape 
y_pred1=np.array(y_pred)
y_pred2=np.mean(y_pred1,axis=0)

r1,c1=y_pred2.shape
print y_pred2[0:5]
print (r1,c1)
pred=np.reshape(y_pred2,(r1*c1,1))[:,0]
print (pred.shape)

# %% [markdown]
# ### create submission

# %%
submissionFolder='./output/submissions'
if not os.path.exists(submissionFolder):
        os.mkdir(submissionFolder)

        
submission = pd.DataFrame({'id': learder['id'], 'is_iceberg': pred})
now = datetime.datetime.now()
info=experiment
suffix = info + '_' + str(now.strftime("%Y-%m-%d-%H-%M"))
path2submission = os.path.join('./output/submissions', 'submission_' + suffix + '.csv')
print (path2submission)
submission.to_csv(path2submission, index=False)
submission.head()
